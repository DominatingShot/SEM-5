# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#QN1
x = np.array([1,1,2,3,4,3,4,6,4])
t0 = 1.2
t1 = 0.5
y=t0+t1*x
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('h(x)')
plt.title('Linear Regression')
plt.show()

# %%
#QN2
B=np.array([2,1,0.5, 1, 3, 3, 2, 5, 4])
print(np.dot(x,B))
# Out:
# 82.0

# %%
#QN3
plt.plot(x,B)
plt.xlabel('x')
plt.ylabel('B')
plt.show()

# %%
#QN4
n=x.shape[0]
print(n)
C=x-B
print(C)
C=C**2
print(C)
C=C.sum()
print(C)
C=C/n
print(C)
# Out:
# 9
# [-1.   0.   1.5  2.   1.   0.   2.   1.   0. ]
# [1.   0.   2.25 4.   1.   0.   4.   1.   0.  ]
# 13.25
# 1.4722222222222223

# %%
#QN5
def compute_cost_function(n,t1,A,B):
    cost=0
    for i in range(0,n):
        hx=t1*A[i]
        cost=cost+(hx-B[i])**2
    cost=cost/(2*n)
    return cost
